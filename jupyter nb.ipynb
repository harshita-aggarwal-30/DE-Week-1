# %% [markdown]
# > Add blockquote
#
# 1.Load data into data frames:

# %%
import pandas as pd
csv=pd.read_csv("/content/Combined_dataset.csv")
csv
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %% [markdown]
# 2.Explore data : Head , Tail , Shape , Columns , Datatypes.

# %%
csv.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
csv.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
csv.shape
# Out:
# (1000, 24)

# %%
csv.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
csv.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %% [markdown]
#  3.Handle missing values (identify, fill/drop).

# %%
csv.fillna(0)
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
csv.dropna ()
# Out:
#      product_id            title  \
# 418    18689340   Flying Machine
# 752    18241626         Roadster
# 753    18241400         Roadster
# 754    18241644         Roadster
# 755    18240570    all about you
# 756    18240582    all about you
# 757    18337610         Roadster
# 760    18241294         Roadster
# 762    18241298         Roadster
# 904    18937522  her by invictus
#
#                                    product_description  rating  ratings_count  \
# 418  Women Black Wide Leg High-Rise Light Fade Crop...     4.3             36
# 752  The  Lifestyle Co. Women Maroon & Black Ribbed...     4.5             25
# 753     Women Black & White Geometric Pullover Sweater     3.8             57
# 754     The  Lifestyle Co. Women Pink Acrylic Pullover     4.3             55
# 755             Women Navy Blue & Red Checked Pullover     4.3             53
# 756                   Women Maroon Cable Knit Pullover     4.4             39
# ...

# %%
csv.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   object
#  2   product_description     1000 non-null   object
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   object
#  8   currency                1000 non-null   object
#  9   images                  1000 non-null   object
#  10  delivery_options        1000 non-null   object
#  11  product_details         1000 non-null   object
#  12  breadcrumbs             1000 non-null   object
#  13  product_specifications  1000 non-null   object
# ...

# %% [markdown]
# 4.Perform basic operations (filter rows, select columns).

# %%
csv[csv["rating"] >= 3.8]
# Out:
#      product_id              title  \
# 0       8376765        Lino Perros
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# ..          ...                ...
# 993    19322504                V2A
# 994     8481603  French Connection
# 996    16896006              GUESS
# 998    19280114           Fastrack
# 999    18601682            BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ...

# %%
rows = {
    "title" : ["Tommy Hilfiger", "French Connection" , "BOLDFIT"],
    "rating": [4.5, 4.5, 3.8],
    "discount": [35.0, 70.0, 31.0]
}
csv=csv.filter(rows)

# %%
csv.usecol=["title", "rating", "discount"]

# %%
csv.rating
# Out:
# 0      3.8
# 1      4.5
# 2      4.4
# 3      4.4
# 4      4.7
#       ...
# 995    3.5
# 996    5.0
# 997    2.8
# 998    4.3
# 999    3.8
# Name: rating, Length: 1000, dtype: float64

# %%
csv.columns
# Out:
# Index(['title', 'rating', 'discount'], dtype='object')

# %% [markdown]
#  5.Remove duplicates.

# %%
csv.drop_duplicates()
# Out:
#               title  rating  discount
# 0       Lino Perros     3.8      58.0
# 1    Tommy Hilfiger     4.5      35.0
# 2             Lavie     4.4      65.0
# 3            F Gear     4.4      52.0
# 4         MYTRIDENT     4.7      17.0
# ..              ...     ...       ...
# 995           KREDO     3.5      50.0
# 996           GUESS     5.0      45.0
# 997        GIORDANO     2.8      50.0
# 998        Fastrack     4.3      20.0
# 999         BOLDFIT     3.8      31.0
#
# [946 rows x 3 columns]

# %% [markdown]
# 6.Create a derived column (total_amount = price * quantity).

# %%
csv["total_amount"]=csv["final_price"]* csv["ratings_count"]

# %%
csv
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  quantity  \
# 0                       Women Navy Blue Solid Backpack         3
# 1                    Unisex Navy Blue Striped Backpack         4
# 2                       Aries Women Pink Mini Backpack         4
# 3           Unisex Navy & Grey Printed Burner Backpack         4
# 4                             Men Blue Solid Bath Robe         4
# ..                                                 ...       ...
# 995  Men FORTE Silver Automatic Skeleton Analogue W...         3
# ...

# %%
csv["total_amount"].dtypes
# Out:
# dtype('O')

# %%
csv.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'quantity',
#        'ratings_count', 'initial_price', 'discount', 'final_price', 'currency',
#        'images', 'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category', 'total_amount'],
#       dtype='object')

# %%
csv.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# quantity                    int64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# total_amount               object
# dtype: object

# %%
csv["final_price"]=csv["final_price"].astype(int)

# %%
csv["ratings_count"]=csv["ratings_count"].astype(int)

# %%
csv
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  quantity  \
# 0                       Women Navy Blue Solid Backpack         3
# 1                    Unisex Navy Blue Striped Backpack         4
# 2                       Aries Women Pink Mini Backpack         4
# 3           Unisex Navy & Grey Printed Burner Backpack         4
# 4                             Men Blue Solid Bath Robe         4
# ..                                                 ...       ...
# 995  Men FORTE Silver Automatic Skeleton Analogue W...         3
# ...

# %%
csv["total_amount"]=csv["final_price"]* csv["ratings_count"]

# %%
csv["total_amount"]
# Out:
# 0        59925
# 1       194233
# 2       677774
# 3      1762100
# 4        34788
#         ...
# 995     130790
# 996     195800
# 997      39750
# 998      44812
# 999     112539
# Name: total_amount, Length: 1000, dtype: int64

# %%
csv.drop([
    "delivery_options",
    "product_details",
    "breadcrumbs",
    "product_specifications",
    "amount_of_stars"
], axis=1, inplace=True)

# %%
csv.dropna()
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  quantity  \
# 0                       Women Navy Blue Solid Backpack         3
# 1                    Unisex Navy Blue Striped Backpack         4
# 2                       Aries Women Pink Mini Backpack         4
# 3           Unisex Navy & Grey Printed Burner Backpack         4
# 4                             Men Blue Solid Bath Robe         4
# ..                                                 ...       ...
# 995  Men FORTE Silver Automatic Skeleton Analogue W...         3
# ...

# %% [markdown]
# Final cleaned csv file

# %%
csv
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  quantity  \
# 0                       Women Navy Blue Solid Backpack         3
# 1                    Unisex Navy Blue Striped Backpack         4
# 2                       Aries Women Pink Mini Backpack         4
# 3           Unisex Navy & Grey Printed Burner Backpack         4
# 4                             Men Blue Solid Bath Robe         4
# ..                                                 ...       ...
# 995  Men FORTE Silver Automatic Skeleton Analogue W...         3
# ...

# %%
csv.to_csv("cleaned_data.csv", index=False)

# %%
from google.colab import files

files.download("cleaned_data.csv")
